# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/bylat/OneDrive/Рабочий стол/data/kc-house-data.csv")

# %% [markdown]
# # 1 Задание
# ## 1.2 Изучите стоимости недвижимости

# %%
data_price = df[df['price']<3000000] # убрал выбросы
plt.figure(figsize = (3,4))
plt.ticklabel_format(style='plain')
plt.boxplot( data_price['price']);
data_price['price'].mean()
# Out:
# 532483.386263507

# %% [markdown]
# #### средняя стоимость недвижимости ≈ 500000

# %% [markdown]
# ## 1.3 Изучите распределение квадратуры жилой

# %%
plt.hist(df['sqft_living'], bins= 50)
plt.xlabel('weights')
plt.ylabel('count')
plt.title('area distribution');

# %% [markdown]
# ## 2.1.4 Изучите распределение года постройки

# %%
plt.boxplot(df['yr_built'])
plt.xlabel('weights')
plt.ylabel('count')
plt.title('Average year of construction');
print(df['yr_built'].mean())
# Out:
# 1971.0051357978994

# %% [markdown]
# ### Исходя из графиков выше можно понять,:
# #### 1. что средняя стоимость недвижимости составляет примерно 500000
# #### 2. больше все домов с площадью от 1500 до 2500
# #### 3. Основной фонд старше 20 лет

# %% [markdown]
# # Задание 2

# %% [markdown]
# ## 2.1 Изучите распределение домов от наличия вида на набережную

# %%
data_waterfront = df['waterfront'].value_counts()
name = data_waterfront.index
value = data_waterfront.values
plt.pie(value, labels=name, autopct='%.1f%%')
plt.title('distribution along the coastline');

# %% [markdown]
# ## 2.2 Изучите распределение этажей домов

# %%
data_floors = df['floors'].value_counts()
name = data_floors.index
value = data_floors.values
plt.bar(name, value)
plt.title('distribution along the coastline');

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ## 2.2 Изучите распределение состояния домов

# %%
data_condition = df['condition'].value_counts()
plt.pie(data_condition.values, labels=data_condition.index, autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x25703cb2ee0>,
# ...
#  [Text(-0.49690197886140836, 0.9813706860323558, '3'),
#   Text(0.21000073456107682, -1.0797683508437392, '4'),
#   Text(1.0489088894797076, -0.33134595451045795, '5'),
#   Text(1.0993745907520605, -0.03708785796914586, '2'),
#   Text(1.0999895419218622, -0.004796630330982164, '1')],
#  [Text(-0.27103744301531363, 0.535293101472194, '64.9%'),
#   Text(0.1145458552151328, -0.5889645550056759, '26.3%'),
#   Text(0.572132121534386, -0.1807341570057043, '7.9%'),
#   Text(0.5996588676829421, -0.020229740710443193, '0.8%'),
#   Text(0.5999942955937428, -0.0026163438168993617, '0.1%')])

# %% [markdown]
# ### Выводы:
# ### 1. Менее 1% домов находятся на набережной
# ### 2. В основном фонд состоит из 1-2 этажных домов
# ### 3. Менее 1% домов в неудовлетворительном состоянии

# %% [markdown]
# # Условие 3: 3 задача
# ## Исследуйте, какие характеристики недвижимости влияют на стоимость недвижимости.

# %%
data_corr = df.corr()
sort_df = data_corr.sort_values('price', ascending=False).drop(['price'])

# %%
plt.figure(figsize = (12,4))
plt.bar(sort_df.index, sort_df['price'])
plt.xticks(rotation = 80);

# %% [markdown]
# ### На данной диаграмме видна зависимость стоимости от следующих характеристик в порядке убывания корреляции.
